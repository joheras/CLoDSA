# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/joheras/CLoDSA/blob/master/notebooks/CLODSA_Plants.ipynb)

# %% [markdown]
# # Augmenting a dataset for object detection
#
# In this notebook, we illustrate how CLODSA can be employed to augment a dataset of images devoted to object detection. In particular, we use the [Plant Phenotyping dataset for object detection](https://www.plant-phenotyping.org/datasets-home) - from now on we will call this dataset, the Plant dataset.

# %% [markdown]
# The Plant training dataset for object detection, presented in the paper ["Finely-grained annotated datasets for image-based plant phenotyping"](https://www.sciencedirect.com/science/article/pii/S0167865515003645#sec0007), consists of 70 tray images where plants can be arranged in a grid, either fixed in position in specialized trays or not and can even be touching each other, the latter leading to a non trivial detection problem. For illustration purposes, we take a subset of the Plant dataset containing 27 images. Such a subset can be downloaded by executing the following command.

# %%
# !wget https://www.dropbox.com/s/9mtp7x8lpvw7alt/Tray.zip?dl=0 -O Tray.zip
# !unzip Tray.zip
# Out:
# --2018-05-12 08:14:19--  https://www.dropbox.com/s/9mtp7x8lpvw7alt/Tray.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.9.1, 2620:100:6031:1::a27d:5101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.9.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dl.dropboxusercontent.com/content_link/6wWkqrnMT7vrUxODkI5w1mKBhyfJ4SP2vZtvejWlaBb8X1EYzBKUFlXbOAvqmnjn/file [following]
# --2018-05-12 08:14:19--  https://dl.dropboxusercontent.com/content_link/6wWkqrnMT7vrUxODkI5w1mKBhyfJ4SP2vZtvejWlaBb8X1EYzBKUFlXbOAvqmnjn/file
# Resolving dl.dropboxusercontent.com (dl.dropboxusercontent.com)... 162.125.66.6, 2620:100:601f:6::a27d:906
# Connecting to dl.dropboxusercontent.com (dl.dropboxusercontent.com)|162.125.66.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 323730838 (309M) [application/zip]
# Saving to: ‘Tray.zip’
#
# Tray.zip            100%[===================>] 308.73M  29.8MB/s    in 11s
#
# 2018-05-12 08:14:32 (28.1 MB/s) - ‘Tray.zip’ saved [323730838/323730838]
#
# Archive:  Tray.zip
#    creating: Tray/
#    creating: Tray/Ara2013-Canon/
#   inflating: Tray/Ara2013-Canon/ara2013_tray27_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray27_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray26_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray26_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray25_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray25_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray24_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray24_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray23_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray23_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray22_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray22_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray21_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray21_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray20_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray20_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray19_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray19_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray18_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray18_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray17_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray17_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray16_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray16_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray15_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray15_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray14_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray14_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray13_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray13_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray12_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray12_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray11_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray11_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray10_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray10_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray09_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray09_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray08_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray08_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray07_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray07_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray06_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray06_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray05_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray05_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray04_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray04_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray03_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray03_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray02_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray02_bbox.csv
#   inflating: Tray/Ara2013-Canon/ara2013_tray01_rgb.png
#   inflating: Tray/Ara2013-Canon/ara2013_tray01_bbox.csv

# %% [markdown]
# We can check the amount of images in each one of the folders.

# %%
print("Number of images in the folder")
# !ls -1 Tray/Ara2013-Canon/*.png | wc -l
# Out:
# Number of images in the folder
# 27

# %% [markdown]
# ## Preparing the dataset
#
# Each image of the Plant dataset is annotated with a comma-separated value (CSV) file reporting for each plant the corner pixel coordinates of its bounding box. This format is not currently supported by the CLODSA library, so we provide a script that convert the CSV files to xml files following the [PASCAL VOC format](https://link.springer.com/article/10.1007/s11263-009-0275-4) - a common format employed in object detection problems and that is already supported by CLODSA.

# %%
# !wget https://www.dropbox.com/s/tchi6u74q7whe2w/plants_script.py?dl=0 -O plants_script.py
# Out:
# --2018-05-12 08:14:45--  https://www.dropbox.com/s/tchi6u74q7whe2w/plants_script.py?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.9.1, 2620:100:6031:1::a27d:5101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.9.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dl.dropboxusercontent.com/content_link/M2y1UQiY3VEVWSa2GDs5WcOho07M21tWvziJQO0CIuNOxtsFB3BcI3XETIRkVgjH/file [following]
# --2018-05-12 08:14:46--  https://dl.dropboxusercontent.com/content_link/M2y1UQiY3VEVWSa2GDs5WcOho07M21tWvziJQO0CIuNOxtsFB3BcI3XETIRkVgjH/file
# Resolving dl.dropboxusercontent.com (dl.dropboxusercontent.com)... 162.125.66.6, 2620:100:601f:6::a27d:906
# Connecting to dl.dropboxusercontent.com (dl.dropboxusercontent.com)|162.125.66.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3431 (3.4K) [text/x-python]
# Saving to: ‘plants_script.py’
#
# plants_script.py    100%[===================>]   3.35K  --.-KB/s    in 0s
#
# 2018-05-12 08:14:47 (240 MB/s) - ‘plants_script.py’ saved [3431/3431]

# %%
# !pip install imutils
# !python plants_script.py
# Out:
# Collecting imutils
#   Downloading https://files.pythonhosted.org/packages/15/ba/24272ac57159cf255959f9298b8e42f00528be90ce4ccd274b604ae5e32d/imutils-0.4.6.tar.gz
# Building wheels for collected packages: imutils
# done
#   Stored in directory: /content/.cache/pip/wheels/cb/58/9b/7debccbc53159611f67cc7e2e3ed37b217e56e9b40e7ba80c3
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.4.6

# %% [markdown]
# ## Augmentation techniques
#
# In this notebook, we will use the following augmentation techniques:
# - Vertical, horizontal, and vertical-horizontal flips.
# - 180º Rotation.
# - Average blurring.
# - Raise the hue value.

# %% [markdown]
# ## Installing the necessary libraries
#
# In case that CLODSA is not installed in your system, the first task consists in installing it using ``pip``.

# %%
# !pip install clodsa
# Out:
# Collecting clodsa
#   Downloading https://files.pythonhosted.org/packages/78/26/5660d2021aa4306ee066bc30eeb622b73f211530a7b7d08a9f85dd455862/clodsa-1.0.0.tar.gz
# Collecting mahotas (from clodsa)
#   Downloading https://files.pythonhosted.org/packages/66/12/951fe5f9787379f713dcda1598d3cca0b29a909ee8ab656514c9a2817863/mahotas-1.4.4.tar.gz (1.5MB)
#     100% |████████████████████████████████| 1.5MB 7.5MB/s
# Requirement already satisfied: imutils in /usr/local/lib/python2.7/dist-packages (from clodsa) (0.4.6)
# Requirement already satisfied: Keras in /usr/local/lib/python2.7/dist-packages (from clodsa) (2.1.6)
# Collecting commentjson (from clodsa)
#   Downloading https://files.pythonhosted.org/packages/d9/53/5bdd41734bcb7e26d1fd9391c7b61729b69151be77bd930bc4b066dd543f/commentjson-0.6.tar.gz
# Requirement already satisfied: scipy in /usr/local/lib/python2.7/dist-packages (from clodsa) (0.19.1)
# Requirement already satisfied: h5py in /usr/local/lib/python2.7/dist-packages (from clodsa) (2.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python2.7/dist-packages (from clodsa) (1.14.3)
# Collecting progressbar2 (from clodsa)
#   Downloading https://files.pythonhosted.org/packages/ca/49/59a86321fafcc2a57ea37925d35f05b20b076941934afd75ce1fd92b3125/progressbar2-3.37.1-py2.py3-none-any.whl
# Requirement already satisfied: scikit_learn in /usr/local/lib/python2.7/dist-packages (from clodsa) (0.19.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python2.7/dist-packages (from Keras->clodsa) (1.11.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python2.7/dist-packages (from Keras->clodsa) (3.12)
# Collecting python-utils>=2.3.0 (from progressbar2->clodsa)
#   Downloading https://files.pythonhosted.org/packages/eb/a0/19119d8b7c05be49baf6c593f11c432d571b70d805f2fe94c0585e55e4c8/python_utils-2.3.0-py2.py3-none-any.whl
# Building wheels for collected packages: clodsa, mahotas, commentjson
#   Running setup.py bdist_wheel for clodsa ... done
#   Stored in directory: /content/.cache/pip/wheels/83/22/a6/25257fd393a89d9a6e51788f399e870e68c080454a992a3c07
#   Running setup.py bdist_wheel for mahotas ... done
#   Stored in directory: /content/.cache/pip/wheels/ca/ed/a4/e7ca81cf5a4090f5a0a9d256fa98506902e4a25fe3e46b7907
#   Running setup.py bdist_wheel for commentjson ... done
#   Stored in directory: /content/.cache/pip/wheels/72/a3/90/047e693f33aa288b83e847dcdcb715fb72df1a9aa55b5cc728
# Successfully built clodsa mahotas commentjson
# Installing collected packages: mahotas, commentjson, python-utils, progressbar2, clodsa
# Successfully installed clodsa-1.0.0 commentjson-0.6 mahotas-1.4.4 progressbar2-3.37.1 python-utils-2.3.0

# %% [markdown]
# ## Loading the necessary libraries
#
# The first step in the pipeline consists in loading the necessary libraries to apply the data augmentation techniques in CLODSA. We also load some libraries to show the results.

# %%
from matplotlib import pyplot as plt
from clodsa.augmentors.augmentorFactory import createAugmentor
from clodsa.augmentors.generator import Generator
from clodsa.techniques.techniqueFactory import createTechnique
import xml.etree.ElementTree as ET
import cv2
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Creating the augmentor object
#
# As explained in the documentation of CLODSA, we need to specify some parameters for the augmentation process, and use them to create an augmentor object.
#
# _The kind of problem_. In this case, we are working in a detection problem

# %%
PROBLEM = "detection"

# %% [markdown]
# _The annotation mode_. We use the Pascal VOC format.

# %%
ANNOTATION_MODE = "pascalvoc"

# %% [markdown]
# _The input path_. The input path containing the images.

# %%
INPUT_PATH = "Tray/Ara2013-Canon/"

# %% [markdown]
# _The generation mode_. In this case, linear, that is, all the augmentation techniques are applied to all the images of the original dataset.

# %%
GENERATION_MODE = "linear"

# %% [markdown]
# _The output mode_. The generated images will be stored in a new folder called augmented_images.

# %%
OUTPUT_MODE = "pascalvoc"
OUTPUT_PATH= "Tray/Ara2013-Canon"

# %% [markdown]
# Using the above information, we can create our augmentor object.

# %%
augmentor = createAugmentor(PROBLEM,ANNOTATION_MODE,OUTPUT_MODE,GENERATION_MODE,INPUT_PATH,{"outputPath":OUTPUT_PATH})

# %% [markdown]
# ## Adding the augmentation techniques
#
# Now, we define the techniques that will be applied in our augmentation process and add them to our augmentor object. To illustrate the transformations, we will use the following image of the dataset.

# %%
img = cv2.imread("Tray/Ara2013-Canon/ara2013_tray05_rgb.png")
# changing to the BGR format of OpenCV to RGB format for matplotlib
plt.imshow(img[:,:,::-1])

# %% [markdown]
# Just for showing the results of applying data augmentation in an object detection problem, we define a function to read the annotations and another one to show them. This funcionality is not necessary when using CLODSA since it is already implemented in there.

# %%
def boxesFromPascalVOC(labelPath):
    tree = ET.parse(labelPath)
    root = tree.getroot()
    objects = root.findall('object')
    if(len(objects)<1):
        raise Exception("The xml should contain at least one object")
    boxes = []
    for object in objects:
        category = object.find('name').text
        bndbox = object.find('bndbox')
        x  = int(bndbox.find('xmin').text)
        y = int(bndbox.find('ymin').text)
        h = int(bndbox.find('ymax').text)-y
        w = int(bndbox.find('xmax').text) - x
        boxes.append((category, (x, y, w, h)))
    return boxes

# %%
def showBoxes(image,boxes):
    cloneImg = image.copy()
    for (category, (x, y, w, h)) in boxes:
        cv2.rectangle(cloneImg,(x,y),(x+w,y+h),(255,0,0),15)
    plt.imshow(cloneImg[:,:,::-1])

# %% [markdown]
# Now, we show the annotation of the image.

# %%
boxes = boxesFromPascalVOC("Tray/Ara2013-Canon/ara2013_tray05_rgb.xml")
showBoxes(img,boxes)

# %% [markdown]
# #### Vertical flip

# %%
vFlip = createTechnique("flip",{"flip":0})
augmentor.addGenerator(Generator(vFlip))

# %% [markdown]
# Showing the result of applying the transformation.

# %%
plt.figure()
plt.title("Original")
showBoxes(img,boxes)
vFlipGenerator = Generator(vFlip)
vFlipImg,vFlipBoxes = vFlipGenerator.applyForDetection(img,boxes)
plt.figure()
plt.title("Transformed")
showBoxes(vFlipImg,vFlipBoxes)

# %% [markdown]
# #### Horizontal flip

# %%
hFlip = createTechnique("flip",{"flip":1})
augmentor.addGenerator(Generator(hFlip))

# %% [markdown]
# Showing the result of applying the transformation.

# %%
plt.figure()
plt.title("Original")
showBoxes(img,boxes)
hFlipGenerator = Generator(hFlip)
hFlipImg,hFlipBoxes = hFlipGenerator.applyForDetection(img,boxes)
plt.figure()
plt.title("Transformed")
showBoxes(hFlipImg,hFlipBoxes)

# %% [markdown]
# #### Horizontal and vertical flip

# %%
hvFlip = createTechnique("flip",{"flip":-1})
augmentor.addGenerator(Generator(hvFlip))

# %% [markdown]
# Showing the result of applying the transformation.

# %%
plt.figure()
plt.title("Original")
showBoxes(img,boxes)
hvFlipGenerator = Generator(hvFlip)
hvFlipImg,hvFlipBoxes = hvFlipGenerator.applyForDetection(img,boxes)
plt.figure()
plt.title("Transformed")
showBoxes(hvFlipImg,hvFlipBoxes)

# %% [markdown]
# #### Rotation:

# %%
rotate = createTechnique("rotate", {"angle" : 90})
augmentor.addGenerator(Generator(rotate))

# %% [markdown]
# Showing the result of applying the transformation.

# %%
plt.figure()
plt.title("Original")
showBoxes(img,boxes)
rotateGenerator = Generator(rotate)
rotateImg,rotateBoxes = rotateGenerator.applyForDetection(img,boxes)
plt.figure()
plt.title("Transformed")
showBoxes(rotateImg,rotateBoxes)

# %% [markdown]
# #### Average blurring

# %%
avgBlur =  createTechnique("average_blurring", {"kernel" : 5})
augmentor.addGenerator(Generator(avgBlur))

# %% [markdown]
# Showing the result of applying the transformation.

# %%
plt.figure()
plt.title("Original")
showBoxes(img,boxes)
avgBlurGenerator = Generator(avgBlur)
avgBlurImg,avgBlurBoxes = avgBlurGenerator.applyForDetection(img,boxes)
plt.figure()
plt.title("Transformed")
showBoxes(avgBlurImg,avgBlurBoxes)

# %% [markdown]
# #### Raise Hue

# %%
hue = createTechnique("raise_hue", {"power" : 0.9})
augmentor.addGenerator(Generator(hue))

# %% [markdown]
# Showing the result of applying the transformation.

# %%
plt.figure()
plt.title("Original")
showBoxes(img,boxes)
hueGenerator = Generator(hue)
hueImg,hueBoxes = hueGenerator.applyForDetection(img,boxes)
plt.figure()
plt.title("Transformed")
showBoxes(hueImg,hueBoxes)

# %% [markdown]
# #### None
# (to keep also the original image)

# %%
none = createTechnique("none",{})
augmentor.addGenerator(Generator(none))

# %% [markdown]
# ## Applying the augmentation process
#
# Finally, we apply the augmentation process (this might take some time depending on the number of images of the original dataset and the number of transformations that will be applied).

# %%
augmentor.applyAugmentation()
# Out:
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24

# %% [markdown]
# Finally, we can check the amount of images in the output folder.

# %%
print("Number of images in the folder")
# !ls -1 Tray/Ara2013-Canon/*.png | wc -l
# Out:
# Number of images in the folder
# 216
