# %%
from techniques.techniqueFactory import createTechnique
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("../sample_images/cat1.jpg")

# %%
t = createTechnique("cropSize", {"x" : 500,"y":500,"width":700,"height":500})

# %%
img1 = t.apply(img)

# %%
plt.imshow(img1[:,:,::-1])

# %%
inputPath = '/home/jonathan/Escritorio/tmp/pycococreator/examples/shapes/train/shapes_train2018'
outputPath = '/home/jonathan/Escritorio/tmp/pycococreator/examples/shapes/train/output/'

from techniques.averageBlurringAugmentationTechnique import averageBlurringAugmentationTechnique
from techniques.bilateralBlurringAugmentationTechnique import bilateralBlurringAugmentationTechnique
from techniques.gaussianNoiseAugmentationTechnique import gaussianNoiseAugmentationTechnique
from techniques.rotateAugmentationTechnique import rotateAugmentationTechnique
from techniques.flipAugmentationTechnique import flipAugmentationTechnique
from techniques.noneAugmentationTechnique import noneAugmentationTechnique
from augmentors.generator import Generator
from techniques.technique import DecoratorTechnique
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-71678356246a> in <module>
#       8 from techniques.flipAugmentationTechnique import flipAugmentationTechnique
#       9 from techniques.noneAugmentationTechnique import noneAugmentationTechnique
# ---> 10 from augmentors.generator import Generator
#      11 from techniques.technique import DecoratorTechnique
#
# ~/PycharmProjects/clodsa_dist/clodsa/augmentors/__init__.py in <module>
#       1 from .augmentorFactory import *
# ----> 2 from .generator import Generator
#
# ~/PycharmProjects/clodsa_dist/clodsa/augmentors/generator.py in <module>
#       2 from builtins import object
#       3 from .detection import detectBox,detectBoxes
# ----> 4 from ..techniques.technique import PositionVariantTechnique,PositionInvariantTechnique,DecoratorTechnique
#       5
#       6
#
# ValueError: attempted relative import beyond top-level package
